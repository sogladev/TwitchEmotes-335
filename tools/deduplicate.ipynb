# %% [markdown]
# Tool to prevent duplicate emoji imports by comparing new .png images against existing .tga emojis, using perceptual similarity instead of filenames.
#
# We’ll use imagededups library's Perceptual Hashing (PHASH) which should work for emoji-like graphics.
#
# TLDR;
#
# Load existing .tga emojis from Emotes/
#
# Convert them to a comparable format (.png in memory, since imagededup uses PIL).
#
# Load new .png emojis from ~/tmp/Emojis.
#
# Compare similarity between each new .png and existing .tga.
#
# Sort proposed candidates and duplicates

# %%
import shutil
from pathlib import Path
from imagededup.methods import PHash
from PIL import Image
import numpy as np

# %%
EMOTES_DIR = Path("../Emotes")
TMP_DIR = Path("~/tmp/Emojis").expanduser()
RESULTS_DIR = Path("~/tmp/Emojis_Results").expanduser()
OUTPUT_DIR = RESULTS_DIR / "Emojis_New"
DUPLICATE_DIR = RESULTS_DIR / "Emojis_Duplicates"
EXISTING_DUP_DIR = DUPLICATE_DIR / 'existing'
CANDIDATE_DUP_DIR = DUPLICATE_DIR / 'candidate'

def clear_folder(folder):
    if folder.exists():
        print(f"⚠️ Warning: {folder} exists, clearing all files.")
        for f in folder.iterdir():
            if f.is_file():
                f.unlink()
            elif f.is_dir():
                shutil.rmtree(f)
    else:
        folder.mkdir(parents=True, exist_ok=True)

for d in [RESULTS_DIR, OUTPUT_DIR, DUPLICATE_DIR, EXISTING_DUP_DIR, CANDIDATE_DUP_DIR]:
    clear_folder(d)
# Out:
# ⚠️ Warning: /home/pc/tmp/Emojis_Results exists, clearing all files.

# %%
# Init perceptual hash model
phasher = PHash()

# Encode all images (existing and new) into a single encoding map
all_encodings = {}

# Add existing .tga emoji encodings
for img_path in EMOTES_DIR.rglob("*.tga"):
    try:
        img = Image.open(img_path).convert("RGB")
        img_array = np.array(img)
        hash_val = phasher.encode_image(image_array=img_array)
        all_encodings[str(img_path)] = hash_val
    except Exception as e:
        print(f"⚠️ Skipping {img_path}: {e}")

# Add new .png emoji encodings
png_encodings = phasher.encode_images(image_dir=str(TMP_DIR))
for filename, hash_val in png_encodings.items():
    all_encodings[str(TMP_DIR / filename)] = hash_val

# Find duplicates in the combined set
duplicates = phasher.find_duplicates(encoding_map=all_encodings, scores=True)

# Print and copy non-duplicate PNGs to OUTPUT_DIR, move duplicates to subfolders
for filename in png_encodings.keys():
    full_path = str(TMP_DIR / filename)
    dups = duplicates.get(full_path, [])
    is_existing_dup = False
    is_candidate_dup = False
    for dup_name, score in dups:
        if dup_name == full_path:
            continue
        score_str = f"{score:.2f}"
        if str(EMOTES_DIR) in dup_name:
            is_existing_dup = True
            # Copy to existing subfolder with clear name and score
            out_name = f"{filename}__DUPLICATE_OF__{Path(dup_name).name}__SCORE_{score_str}.png"
            shutil.copy2(TMP_DIR / filename, EXISTING_DUP_DIR / out_name)
            print(f"🚫 {filename} is a duplicate of existing emoji: {Path(dup_name).name} (score={score_str})")
        elif str(TMP_DIR) in dup_name:
            is_candidate_dup = True
            # Copy to candidate subfolder with clear name and score
            out_name = f"{filename}__DUPLICATE_OF__{Path(dup_name).name}__SCORE_{score_str}.png"
            shutil.copy2(TMP_DIR / filename, CANDIDATE_DUP_DIR / out_name)
            print(f"⚠️ {filename} is a duplicate of another new emoji: {Path(dup_name).name} (score={score_str})")
    if not is_existing_dup and not is_candidate_dup:
        print(f"✅ Adding new emoji: {filename}")
        shutil.copy2(TMP_DIR / filename, OUTPUT_DIR / filename)
# Out:
# 2025-09-07 06:16:11,488: INFO Start: Calculating hashes...
# 100%|██████████| 141/141 [00:00<00:00, 2718.14it/s]
# 2025-09-07 06:16:11,634: INFO End: Calculating hashes!
# 2025-09-07 06:16:11,636: INFO Start: Evaluating hamming distances for getting duplicates
# 2025-09-07 06:16:11,636: INFO Start: Retrieving duplicates using Cython Brute force algorithm
#
# 2025-09-07 06:16:11,634: INFO End: Calculating hashes!
# 2025-09-07 06:16:11,636: INFO Start: Evaluating hamming distances for getting duplicates
# 2025-09-07 06:16:11,636: INFO Start: Retrieving duplicates using Cython Brute force algorithm
# 100%|██████████| 3673/3673 [00:00<00:00, 6257.25it/s]
# 2025-09-07 06:16:12,321: INFO End: Retrieving duplicates using Cython Brute force algorithm
# 2025-09-07 06:16:12,321: INFO End: Evaluating hamming distances for getting duplicates
#
# 2025-09-07 06:16:12,321: INFO End: Retrieving duplicates using Cython Brute force algorithm
# 2025-09-07 06:16:12,321: INFO End: Evaluating hamming distances for getting duplicates
# ✅ Adding new emoji: alliance_wow.png
# ✅ Adding new emoji: AngryNelfNoisesIntensify.gif
# ✅ Adding new emoji: AngryNightElfNoises.png
# ✅ Adding new emoji: azerothcore.png
# ✅ Adding new emoji: basement.png
# ✅ Adding new emoji: bedge.png
# ✅ Adding new emoji: blizzard.png
# ✅ Adding new emoji: bloodelf_f.png
# ✅ Adding new emoji: bloodelf_m.png
# ✅ Adding new emoji: bongobutt.gif
# ✅ Adding new emoji: CatOK.png
# ✅ Adding new emoji: CavemanBob.png
# ✅ Adding new emoji: CcAngryNelfNoises.png
# ✅ Adding new emoji: CcAriseMyChampion2.png
# ✅ Adding new emoji: ccbench.png
# ✅ Adding new emoji: ccbonk.gif
# ✅ Adding new emoji: ccbonk1.png
# ✅ Adding new emoji: ccbonk2.png
# ✅ Adding new emoji: ccbonk3.png
# ✅ Adding new emoji: CcCryingDruid2.png
# ✅ Adding new emoji: ccgrinch.png
# ✅ Adding new emoji: cchappyGe.png
# ✅ Adding new emoji: CcKekThas.png
# ✅ Adding new emoji: ccKneecap.png
# 🚫 ccMonkaS.png is a duplicate of existing emoji: monkaS.tga (score=4.00)
# 🚫 ccMonkaS.png is a duplicate of existing emoji: tyler1Monk.tga (score=6.00)
# 🚫 ccMonkaS.png is a duplicate of existing emoji: monkaGasp.tga (score=8.00)
# 🚫 ccMonkaS.png is a duplicate of existing emoji: monkaLaugh.tga (score=8.00)
# 🚫 ccMonkaS.png is a duplicate of existing emoji: nanoMEGA.tga (score=10.00)
# ✅ Adding new emoji: CcMrrgl.png
# ✅ Adding new emoji: CcMrrlBlush.png
# ✅ Adding new emoji: CcOrcLewd.png
# ✅ Adding new emoji: CcPensiveCowboy.png
# ✅ Adding new emoji: CCpin.gif
# ✅ Adding new emoji: ccping.png
# ✅ Adding new emoji: ccpoo.png
# ✅ Adding new emoji: CcRagnarosCool.png
# ✅ Adding new emoji: ccslap.png
# ✅ Adding new emoji: CcSmug.png
# ✅ Adding new emoji: ccSoon.png
# 🚫 ccSoon2.png is a duplicate of existing emoji: peepoLip.tga (score=10.00)
# ⚠️ CcSuccubusKiss.png is a duplicate of another new emoji: CcSuccubusKiss_Shadow.png (score=2.00)
# ⚠️ CcSuccubusKiss.png is a duplicate of another new emoji: CcSuccubusKiss_Fel.png (score=6.00)
# ⚠️ CcSuccubusKiss_Fel.png is a duplicate of another new emoji: CcSuccubusKiss.png (score=6.00)
# ⚠️ CcSuccubusKiss_Fel.png is a duplicate of another new emoji: CcSuccubusKiss_Shadow.png (score=8.00)
# ⚠️ CcSuccubusKiss_Shadow.png is a duplicate of another new emoji: CcSuccubusKiss.png (score=2.00)
# ⚠️ CcSuccubusKiss_Shadow.png is a duplicate of another new emoji: CcSuccubusKiss_Fel.png (score=8.00)
# ✅ Adding new emoji: CcSurprisedMurloc.png
# ✅ Adding new emoji: CcSurprisedMurloc~1.png
# ✅ Adding new emoji: ccThis.png
# 🚫 CcThx.png is a duplicate of existing emoji: pgeRay.tga (score=10.00)
# ✅ Adding new emoji: ccuwu.png
# ⚠️ CcYrelHello.png is a duplicate of another new emoji: CcYrelHi.png (score=0.00)
# ⚠️ CcYrelHi.png is a duplicate of another new emoji: CcYrelHello.png (score=0.00)
# ✅ Adding new emoji: chromiecraft.png
# ⚠️ copper.png is a duplicate of another new emoji: silver.png (score=2.00)
# ⚠️ copper.png is a duplicate of another new emoji: gold.png (score=4.00)
# ✅ Adding new emoji: deathknight.png
# 🚫 dedge.png is a duplicate of existing emoji: Deadge.tga (score=10.00)
# ✅ Adding new emoji: derby.png
# ✅ Adding new emoji: derbyram.png
# ✅ Adding new emoji: DisgustedRamsay.png
# ✅ Adding new emoji: draenei_f.png
# ✅ Adding new emoji: draenei_m.png
# ⚠️ druid.png is a duplicate of another new emoji: hunter.png (score=10.00)
# ✅ Adding new emoji: dwarf_f.png
# ✅ Adding new emoji: dwarf_m.png
# ✅ Adding new emoji: F_.png
# ✅ Adding new emoji: FeelsBadMan.png
# ✅ Adding new emoji: FeelsCryingMan.png
# 🚫 FeelsNiceMan.png is a duplicate of existing emoji: HYPERS.tga (score=2.00)
# 🚫 FeelsTooGood.png is a duplicate of existing emoji: peepoCry.tga (score=2.00)
# ✅ Adding new emoji: gnome_f.png
# ✅ Adding new emoji: gnome_m.png
# ⚠️ gold.png is a duplicate of another new emoji: silver.png (score=2.00)
# ⚠️ gold.png is a duplicate of another new emoji: copper.png (score=4.00)
# ✅ Adding new emoji: horde_wow.png
# ✅ Adding new emoji: human_f.png
# ✅ Adding new emoji: human_m.png
# ⚠️ hunter.png is a duplicate of another new emoji: druid.png (score=10.00)
# ✅ Adding new emoji: KekWait.png
# ✅ Adding new emoji: mage.png
# ✅ Adding new emoji: mile.png
# ✅ Adding new emoji: NelfGasp.png
# ✅ Adding new emoji: nightelf_f.png
# ✅ Adding new emoji: nightelf_m.png
# ✅ Adding new emoji: NoCap.png
# ✅ Adding new emoji: ofc.png
# ✅ Adding new emoji: oldge.png
# ✅ Adding new emoji: omgitshacki.png
# ✅ Adding new emoji: orc_f.png
# ✅ Adding new emoji: orc_m.png
# ✅ Adding new emoji: paladin.png
# ✅ Adding new emoji: pepeApproved.png
# ✅ Adding new emoji: pepeBAN.png
# ✅ Adding new emoji: pepeBirthday.png
# ✅ Adding new emoji: pepeBlush.png
# ✅ Adding new emoji: pepeChristmas.png
# ✅ Adding new emoji: pepeHeartbroken.png
# ✅ Adding new emoji: pepeHmmmYEAH.png
# ✅ Adding new emoji: pepeHYPE.png
# ✅ Adding new emoji: pepeInspect.png
# ✅ Adding new emoji: pepeJAM.gif
# ✅ Adding new emoji: pepeMusk.png
# 🚫 pepeNo.png is a duplicate of existing emoji: PepeNo.tga (score=0.00)
# ✅ Adding new emoji: pepeNoStonks.png
# ✅ Adding new emoji: pepePopcorn.png
# ✅ Adding new emoji: pepeRules.png
# ✅ Adding new emoji: pepeSalute.png
# ✅ Adding new emoji: pepeSmart.png
# ✅ Adding new emoji: pepeStonks.png
# ✅ Adding new emoji: pepeWhocares.png
# 🚫 pepeWhoknows.png is a duplicate of existing emoji: peepoBored.tga (score=8.00)
# 🚫 pepeWhoknows.png is a duplicate of existing emoji: peepoShy.tga (score=8.00)
# 🚫 pepeWhoknows.png is a duplicate of existing emoji: Madge.tga (score=10.00)
# 🚫 pepeWhoknows.png is a duplicate of existing emoji: ehWTF.tga (score=10.00)
# 🚫 pepeWhoknows.png is a duplicate of existing emoji: peepoThink.tga (score=10.00)
# ✅ Adding new emoji: pepeWOKE.png
# ✅ Adding new emoji: pepeWUT.png
# 🚫 pepeYes.png is a duplicate of existing emoji: PepeYes.tga (score=4.00)
# 🚫 pepeYes.png is a duplicate of existing emoji: peepoMaybe.tga (score=6.00)
# 🚫 POG.png is a duplicate of existing emoji: PagChomp.tga (score=4.00)
# ✅ Adding new emoji: priest.png
# ✅ Adding new emoji: rogue.png
# 🚫 sadge.png is a duplicate of existing emoji: Sadge.tga (score=0.00)
# 🚫 sadge.png is a duplicate of existing emoji: Notsurege.tga (score=6.00)
# 🚫 sadge.png is a duplicate of existing emoji: Okayge.tga (score=6.00)
# 🚫 sadge.png is a duplicate of existing emoji: Stronge.tga (score=6.00)
# 🚫 sadge.png is a duplicate of existing emoji: Gladge.tga (score=8.00)
# 🚫 sadge.png is a duplicate of existing emoji: Nerdge.tga (score=8.00)
# 🚫 sadge.png is a duplicate of existing emoji: Weirdge.tga (score=8.00)
# 🚫 sadge.png is a duplicate of existing emoji: Yepge.tga (score=8.00)
# 🚫 sadge.png is a duplicate of existing emoji: Hmmge.tga (score=10.00)
# 🚫 sadge.png is a duplicate of existing emoji: Madge.tga (score=10.00)
# 🚫 sadge.png is a duplicate of existing emoji: Pepege.tga (score=10.00)
# 🚫 sadge.png is a duplicate of existing emoji: Prayge.tga (score=10.00)
# 🚫 sadge.png is a duplicate of existing emoji: Susge.tga (score=10.00)
# ✅ Adding new emoji: sedgeboots.png
# ✅ Adding new emoji: sgeheart.png
# ✅ Adding new emoji: Shaman.png
# ⚠️ silver.png is a duplicate of another new emoji: copper.png (score=2.00)
# ⚠️ silver.png is a duplicate of another new emoji: gold.png (score=2.00)
# ✅ Adding new emoji: Sylv.png
# ✅ Adding new emoji: tauren_f.png
# ✅ Adding new emoji: tauren_m.png
# ✅ Adding new emoji: tea.png
# ✅ Adding new emoji: TOS.png
# ✅ Adding new emoji: troll_f.png
# ✅ Adding new emoji: troll_m.png
# ✅ Adding new emoji: undead_f.png
# ✅ Adding new emoji: undead_m.png
# ✅ Adding new emoji: VeryAngryNelfNoises.gif
# ✅ Adding new emoji: warlock.png
# ✅ Adding new emoji: warrior.png
# ✅ Adding new emoji: weirdge.png
# ✅ Adding new emoji: whip.png
# ✅ Adding new emoji: wokege.png
# ✅ Adding new emoji: worldofwarcraft.png
# ✅ Adding new emoji: wow_raid_circle.png
# ✅ Adding new emoji: wow_raid_cross.png
# ✅ Adding new emoji: wow_raid_diamond.png
# ✅ Adding new emoji: wow_raid_moon.png
# ✅ Adding new emoji: wow_raid_skull.png
# ✅ Adding new emoji: wow_raid_square.png
# ✅ Adding new emoji: wow_raid_star.png
# ✅ Adding new emoji: wow_raid_triangle.png
# ✅ Adding new emoji: YeaBoi.png
# ✅ Adding new emoji: YEP.png
